# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajaykumar-02/NLP/blob/main/Tf_idf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from numpy import vectorize
documnets = [
    "I love pizza",
    "Pizza is the best",
    "I love pasta",
    "Pasta is great"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documnets)

print("Vocabulary:", vectorizer.get_feature_names_out())
print("\nBow Matrix:\n",X.toarray())
# Out:
# Vocabulary: ['best' 'great' 'is' 'love' 'pasta' 'pizza' 'the']
#
# Bow Matrix:
#  [[0.         0.         0.         0.70710678 0.         0.70710678
#   0.        ]
#  [0.55528266 0.         0.43779123 0.         0.         0.43779123
#   0.55528266]
#  [0.         0.         0.         0.70710678 0.70710678 0.
#   0.        ]
#  [0.         0.66767854 0.52640543 0.         0.52640543 0.
#   0.        ]]
